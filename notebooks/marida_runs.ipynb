# %% [markdown]
# ### Notebook used for experimental runs in Google Collab pro

# %%
from google.colab import drive, userdata
from huggingface_hub import snapshot_download
from huggingface_hub import login
import os

# %%
drive.mount('/content/drive')
token = userdata.get('githubAccess')
os.environ['WANDB_API_KEY'] = userdata.get('wandbKey')
os.environ['HF_TOKEN'] = userdata.get('hfToken')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q timm rasterio wandb
# !pip install huggingface_hub -q

# %%
# %cd /content/drive/MyDrive/Coursework_INM705_PlasticDebris_Segmentation/src/u-net-vit
# Out:
# /content/drive/MyDrive/Coursework_INM705_PlasticDebris_Segmentation/src/u-net-vit

# %%
#%cd /content/drive/MyDrive/Coursework_INM705_PlasticDebris_Segmentation

# !git pull
# Out:
# Already up to date.

# %%
# !cp -r /content/drive/MyDrive/Coursework_INM705_PlasticDebris_Segmentation/data/data.tar /content/

# %%
# !tar -xvf /content/data.tar -C /content/

# %%
# !nvidia-smi
# Out:
# Mon Apr 13 19:13:07 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   47C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %cd drive/MyDrive/Coursework_INM705_PlasticDebris_Segmentation/src/u-net-vit/

# %%
# %ls
# Out:
# checkpoints/   evaluation.py  __pycache__/  vit_unet.py
# dataloader.py  logs/          train.py      wandb/

# %%
#!python train.py --epochs 44 --data_path /content/data/MARIDA/ --lr 1e-4 --num_workers 4
#!python train.py --epochs 60 --data_path /content/data/MARIDA/ --lr 1e-4 --num_workers 4 --weight_param 1.009 -- patch 4
#Baseline hyperpameters like paper; learning rate: 2x10^-4, batchsize:5, epochs:44, change lr after epoch 40 to 2^10-5, Adam
#!python train.py --epochs 50 --data_path /content/data/MARIDA/ --num_workers 4 --lr 2e-4 --run_name "run-decay-44 epochs-lr2e-4" --decay 0.05
# !python train.py --epochs 60 --data_path /content/data/MARIDA/ --batch=16 --num_workers 4 --lr 2e-4 --run_name "run-decay-lr2e-4-batch16-epochs-60-REPRODUCIBLE" --decay 0.05
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run qxunfmlm (0.2s)
# wandb: ⣽ setting up run qxunfmlm (0.2s)
# wandb: ⣾ setting up run qxunfmlm (0.2s)
# wandb: ⣷ setting up run qxunfmlm (0.2s)
# wandb: ⣯ setting up run qxunfmlm (0.2s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/drive/MyDrive/Coursework_INM705_PlasticDebris_Segmentation/src/u-net-vit/wandb/run-20260418_082836-qxunfmlm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run run-decay-lr2e-4-batch16-epochs-60-REPRODUCIBLE
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/vit-Unet%20marida-segmentation
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/vit-Unet%20marida-segmentation/runs/qxunfmlm
# Load train set to memory: 100% 694/694 [00:06<00:00, 107.31it/s]
# Load val set to memory: 100% 328/328 [00:03<00:00, 109.15it/s]
# model.safetensors: 100% 346M/346M [00:04<00:00, 81.9MB/s]
# training epoch 1/60: 100% 44/44 [00:34<00:00,  1.26it/s]
# testing: 100% 21/21 [00:05<00:00,  3.62it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# training epoch 2/60:  14% 6/44 [00:04<00:29,  1.28it/s]

# %%
# %cd src/u-net-Baseline/
# !python train.py --epochs 44 --data_path /content/data/MARIDA/ --num_workers 4
